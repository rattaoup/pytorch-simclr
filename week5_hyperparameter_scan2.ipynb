# %%
import os
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
resume_from5 = os.path.join('./checkpoint', 'resnet18_aam_new_gp5_0_n1.pth99')
resume_from0_1 = os.path.join('./checkpoint', 'resnet18_aam_new_gp0_1_n1.pth99')
resume_from0_01 = os.path.join('./checkpoint', 'resnet18_aam_new_gp0_01_n1.pth99')
resume_from0_001 = os.path.join('./checkpoint', 'resnet18_aam_new_gp0_001_n1.pth99')
checkpoint5 = torch.load(resume_from5)
checkpoint0_1 = torch.load(resume_from0_1)
checkpoint0_01 = torch.load(resume_from0_01)
checkpoint0_001 = torch.load(resume_from0_001)
resume_from1_n2 = os.path.join('./checkpoint', 'resnet18_aam_new_gp1_0_n2.pth99')
checkpoint1_n2 = torch.load(resume_from1_n2)

# %%
gp_lambda10 = [0.00299, 0.00195, 0.00168, 0.00154 ,0.00148 ,0.00143 ,0.00139 ,0.00137 ,0.00137 ,0.00135 ]
loss_lambda10 = [5.956, 5.700, 5.614, 5.563 ,5.541 ,5.522 ,5.504 ,5.488 ,5.481 ,5.467]
acc_lambda10 = [52.810, 65.170,  70.410 ,73.100, 74.850 ,76.290, 76.920, 78.030, 78.520 ,79.180]

# %%
gp_lambda1 = [0.00321,0.00211,0.00183,0.00166,0.00159,0.00153,0.00150,0.00152,0.00145,0.00146]
loss_lambda1 = [5.936,5.690,5.606,5.561,5.531,5.510,5.495,5.482,5.468,5.461]
acc_lambda1 = [53.35,65.71,70.94,74.04,75.28,76.86,77.74,78.77,79.3,79.69]

# %%
checkpoint0_1['epoch_list'][5:10]
# Out:
# [59, 69, 79, 89, 99]

# %%
plt.plot(checkpoint0_1['epoch_list'], acc_lambda10, label = 'lambda_gp = 10')
plt.plot(checkpoint0_1['epoch_list'], acc_lambda1, label = 'lambda_gp = 1')
plt.plot(checkpoint5['epoch_list'], checkpoint5['test_acc'], label = 'lambda_gp = 5')
plt.plot(checkpoint0_1['epoch_list'], checkpoint0_1['test_acc'], label = 'lambda_gp = 0.1')
plt.plot(checkpoint0_01['epoch_list'], checkpoint0_01['test_acc'], label = 'lambda_gp = 0.01')
plt.plot(checkpoint0_001['epoch_list'], checkpoint0_001['test_acc'], label = 'lambda_gp = 0.001')
plt.legend()
plt.title('test accuracy 1 - 100')
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'][5:10], acc_lambda10[5:10], label = 'lambda_gp = 10')


plt.plot(checkpoint5['epoch_list'][5:10], checkpoint5['test_acc'][5:10], label = 'lambda_gp = 5')
plt.plot(checkpoint0_1['epoch_list'][5:10], acc_lambda1[5:10], label = 'lambda_gp = 1')
plt.plot(checkpoint0_1['epoch_list'][5:10], checkpoint0_1['test_acc'][5:10], label = 'lambda_gp = 0.1')
plt.plot(checkpoint0_01['epoch_list'][5:10], checkpoint0_01['test_acc'][5:10], label = 'lambda_gp = 0.01')
plt.plot(checkpoint0_001['epoch_list'][5:10], checkpoint0_001['test_acc'][5:10], label = 'lambda_gp = 0.001')
plt.legend()
plt.title('test accuracy 50-100')
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'], loss_lambda10, label = 'lambda_gp = 10')
plt.plot(checkpoint5['epoch_list'], checkpoint5['contrastive_loss'], label = 'lambda_gp = 5')
plt.plot(checkpoint0_1['epoch_list'], loss_lambda1, label = 'lambda_gp = 1')

plt.plot(checkpoint0_1['epoch_list'], checkpoint0_1['contrastive_loss'], label = 'lambda_gp = 0.1')
plt.plot(checkpoint0_01['epoch_list'], checkpoint0_01['contrastive_loss'], label = 'lambda_gp = 0.01')
plt.plot(checkpoint0_001['epoch_list'], checkpoint0_001['contrastive_loss'], label = 'lambda_gp = 0.001')
plt.title('contrastive loss')
plt.legend()
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'][5:10], loss_lambda10[5:10], label = 'lambda_gp = 10')
plt.plot(checkpoint5['epoch_list'][5:10], checkpoint5['contrastive_loss'][5:10], label = 'lambda_gp = 5')
plt.plot(checkpoint0_1['epoch_list'][5:10], loss_lambda1[5:10], label = 'lambda_gp = 1')


plt.plot(checkpoint0_1['epoch_list'][5:10], checkpoint0_1['contrastive_loss'][5:10], label = 'lambda_gp = 0.1')
plt.plot(checkpoint0_01['epoch_list'][5:10], checkpoint0_01['contrastive_loss'][5:10], label = 'lambda_gp = 0.01')
plt.plot(checkpoint0_001['epoch_list'][5:10], checkpoint0_001['contrastive_loss'][5:10], label = 'lambda_gp = 0.001')
plt.title('contrastive loss 50 - 100')
plt.legend()
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'], gp_lambda10, label = 'lambda_gp = 10')
plt.plot(checkpoint5['epoch_list'], checkpoint5['gradient_penalty'], label = 'lambda_gp = 5')
plt.plot(checkpoint0_1['epoch_list'], gp_lambda1, label = 'lambda_gp = 1')

plt.plot(checkpoint0_1['epoch_list'], checkpoint0_1['gradient_penalty'], label = 'lambda_gp = 0.1')
plt.plot(checkpoint0_01['epoch_list'], checkpoint0_01['gradient_penalty'], label = 'lambda_gp = 0.01')
plt.plot(checkpoint0_001['epoch_list'], checkpoint0_001['gradient_penalty'], label = 'lambda_gp = 0.001')
plt.title('gradient_penalty loss')
plt.legend()
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'][5:10], gp_lambda10[5:10], label = 'lambda_gp = 10')
plt.plot(checkpoint5['epoch_list'][5:10], checkpoint5['gradient_penalty'][5:10], label = 'lambda_gp = 5')
plt.plot(checkpoint0_1['epoch_list'][5:10], gp_lambda1[5:10], label = 'lambda_gp = 1')
plt.plot(checkpoint0_1['epoch_list'][5:10], checkpoint0_1['gradient_penalty'][5:10], label = 'lambda_gp = 0.1')
plt.plot(checkpoint0_01['epoch_list'][5:10], checkpoint0_01['gradient_penalty'][5:10], label = 'lambda_gp = 0.01')
plt.plot(checkpoint0_001['epoch_list'][5:10], checkpoint0_001['gradient_penalty'][5:10], label = 'lambda_gp = 0.001')
plt.title('gradient_penalty loss 50 - 100')
plt.legend()
plt.show()

# %% [markdown]
# # Compare norm1 with norm2

# %%
plt.plot(checkpoint0_1['epoch_list'], acc_lambda1, label = 'lambda_gp = 1, norm = 1')
plt.plot(checkpoint0_1['epoch_list'], checkpoint1_n2['test_acc'], label = 'lambda_gp = 1, norm = 2')
plt.legend()
plt.title('test accuracy 1 - 100')
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'], gp_lambda1, label = 'lambda_gp = 1, norm = 1')
plt.plot(checkpoint0_1['epoch_list'], checkpoint1_n2['gradient_penalty'], label = 'lambda_gp = 1, norm = 2')
plt.legend()
plt.title('gradient penalty 1 - 100')
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'], loss_lambda1, label = 'lambda_gp = 1, norm = 1')
plt.plot(checkpoint0_1['epoch_list'], checkpoint1_n2['contrastive_loss'], label = 'lambda_gp = 1, norm = 2')
plt.legend()
plt.title('contrastive loss 1 - 100')
plt.show()

# %%
plt.plot(checkpoint0_1['epoch_list'][5:10], loss_lambda1[5:10], label = 'lambda_gp = 1, norm = 1')
plt.plot(checkpoint0_1['epoch_list'][5:10], checkpoint1_n2['contrastive_loss'][5:10], label = 'lambda_gp = 1, norm = 2')
plt.legend()
plt.title('contrastive loss 50 - 100')
plt.show()

# %% [markdown]
# # scatter plot

# %%
checkpoint0_1['test_acc']
# Out:
# [53.71, 66.07, 70.58, 73.68, 75.87, 76.96, 77.87, 78.52, 78.88, 79.6]

# %%
plt.scatter(loss_lambda10, acc_lambda10, label = 'lambda_gp = 10')
plt.scatter(loss_lambda1, acc_lambda1, label = 'lambda_gp = 1', marker = '^', color = 'orange')
plt.scatter(np.array(checkpoint0_1['contrastive_loss']), np.array(checkpoint0_1['test_acc']), label = 'lambda_gp = 0.1', marker = 'x', color='g')
plt.scatter(np.array(checkpoint0_01['contrastive_loss']), np.array(checkpoint0_01['test_acc']), label = 'lambda_gp = 0.01', marker = 's', color = 'red')
plt.ylabel('accuracy with reg 1e-5')
plt.xlabel('contrastive loss')
plt.title('loss/ accuracy for epoch 1-100')
plt.legend()
plt.show()

# %%
plt.scatter(loss_lambda10[5:10], acc_lambda10[5:10], label = 'lambda_gp = 10')
plt.scatter(loss_lambda1[5:10], acc_lambda1[5:10], label = 'lambda_gp = 1', marker = '^', color = 'orange')
plt.scatter(np.array(checkpoint0_1['contrastive_loss'][5:10]), np.array(checkpoint0_1['test_acc'][5:10]), label = 'lambda_gp = 0.1', marker = 'x', color='g')
plt.scatter(np.array(checkpoint0_01['contrastive_loss'][5:10]), np.array(checkpoint0_01['test_acc'][5:10]), label = 'lambda_gp = 0.01', marker = 's', color = 'red')

# plt.scatter(checkpoint0_1['contrastive_loss'], checkpoint0_1['test_acc'], marker = 'x', color='r', label = 'lambda_gp = 0.1')
# plt.scatter(loss_lambda1000, acc_lambda1000,  marker = 'o', color='g', label = 'lambda_gp = 1000')
plt.ylabel('accuracy with reg 1e-5')
plt.xlabel('contrastive loss')
plt.title('loss/ accuracy for epoch 50-100')
plt.legend()
plt.show()
